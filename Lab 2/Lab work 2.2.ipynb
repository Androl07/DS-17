# %%
#1
numbers = input()
list1 = numbers.split()
list1.sort()
print("Мінімальне число", list1[0])
print("Максимальне число", list1[len(list1) - 1])
# Out:
#  4 9 2
# Мінімальне число 2
# Максимальне число 9

# %%
#2
sex = input()
if sex == 'f' or sex == 'm':
    age = float(input())
    if sex == 'f' and age > 18:
        print("Може брати участь у змаганнях")
    elif sex == 'm' and age > 16:
        print("Може брати участь у змаганнях")
    else:
        print("Не може брати участь у змаганнях")
else:
    print("Введено невірні дані")
# Out:
#  m
#  17
# Може брати участь у змаганнях

# %%
#3
N = int(input("Введіть натуральне число:"))
if N > 0:
    i = 1
    while i <= N:
        print("&"*i)
        i = i + 1
else:
    print("Введено невірні дані")
# Out:
# Введіть натуральне число: 4
# &
# &&
# &&&
# &&&&

# %%
#4
sentence = 'My favourite tutor in academy is Ihor'
list1 = sentence.split()
for i in range(len(list1)):
    print(list1[i], len(list1[i]))
    i = i + 1
# Out:
# My 2
# favourite 9
# tutor 5
# in 2
# academy 7
# is 2
# Ihor 4

# %%
#5
text = """До чого ж гарно і весело було в нашому горóді! Ото як вийти з сіней та подивись навколо — геть-чисто все зелене та буйне. А сад було як зацвіте весною! А що робилось на початку літа — огірки цвітуть, гарбузи цвітуть, картопля цвіте. Цвіте малина, смородина, тютюн, квасоля. А соняшника, а маку, буряків, лободи, укропу, моркви! Чого тільки не насадить наша невгамовна мати.

— Нічого в світі так я не люблю, як саджати що-небудь у землю, щоб проізростало. Коли вилізає з землі всяка рослиночка, ото мені радість,— любила проказувати вона.

Город до того переповнявсь рослинами, що десь серед літа вони вже не вміщалися в ньому. Вони лізли одна на одну, переплітались, душились, дерлися на хлів, на стріху, повзли на тин, а гарбузи звисали з тину прямо на вулицю.

А малини — красної, білої! А вишень, а груш солодких, було. як наїсися,— цілий день живіт як бубон.

І росло ще, пригадую, багато тютюну, в якому ми, маленькі, ходили, мов у лісі, в якому пізнали перші мозолі на дитячих руках.

А вздовж тину, за старою повіткою, росли великі кущі смородини, бузини і ще якихось невідомих рослин. Там неслися кури нишком од матері і різне дрібне птаство. Туди ми рідко лазили. Там було темно навіть удень, і ми боялись гадюки. Хто з нас у дитинстві не боявся гадюки, так за все життя й не побачивши її ніде?

Коло хати, що стояла в саду, цвіли квіти, а за хатою, проти сінешніх дверей, коло вишень,— поросла полином стара погребня з одкритою лядою, звідки завжди пахло цвіллю. Там, у льоху, в присмерку плигали жаби. Напевно, там водилися й гадюки.

На погребні любив спати дід.

У нас був дід дуже схожий на бога. Коли я молився богу, я завжди бачив на покуті портрет діда в старих срібнофольгових шатах, а сам дід лежав на печі і тихо кашляв, слухаючи своїх молитов.

У неділю перед богами горіла маленька синенька лампадка, в яку завжди набиралось повно мух. Образ святого Миколая також був схожий на діда, особливо коли дід часом підстригав собі бороду і випивав перед обідом чарку горілки з перцем, і мати не лаялась. Святий Федосій більш скидався на батька. Федосію я не молився, в нього була ще темна борода, а в руці гирлига, одягнена чомусь у білу хустку. А от бог, схожий на діда, той тримав в одній руці круглу сільничку, а трьома пýчками другої неначе збирався взяти зубок часнику
Звали нашого діда, як я вже потім довідавсь, Семеном. Він був високий і худий, і чоло в нього високе, хвилясте довге волосся сиве, а борода біла. І була в нього велика грижа ще з молодих чумацьких літ. Пахнув дід теплою землею і трохи млином. Він був письменний по-церковному і в неділю любив урочисто читати псалтир. Ні дід, ні ми не розуміли прочитаного, і це завжди хвилювало нас, як дивна таємниця, що надавала прочитаному особливого, небуденного смислу.

Мати ненавиділа діда і вважала його за чорнокнижника. Ми не вірили матері і захищали діда од її нападів, бо псалтир всередині був не чорний, а білий, а товста шкіряна палітурка — коричнева, як гречаний мед чи стара халява. Зрештою, мати крадькома таки знищила псалтир. Вона спалила його в печі по одному листочку, боячись палити зразу весь, щоб він часом не вибухнув і не розніс печі.

Любив дід гарну бесіду й добре слово. Часом по дорозі на луг, коли хто питав у нього дорогу на Борзну чи на Батурин, він довго стояв посеред шляху і, махаючи пужалном, гукав услід подорожньому:

— Прямо, та й прямо, та й прямо, та й нікуди ж не звертайте!.. Добра людина поїхала, дай їй бог здоров'я,— зітхав він лагідно, коли подорожній нарешті зникав у кущах.

— А хто вона, діду, людина ота? Звідки вона?

— А бог її знає, хіба я знаю... Ну, чого стоїш як укопаний? — звертався дід до коня, сідаючи на воза.— Но, трогай-бо, ну...

Він був наш добрий дух лугу і риби. Гриби й ягоди збирав він у лісі краще за нас усіх і розмовляв з кіньми, з телятами, з травами, з старою грушею і дубом — з усім живим, що росло і рухалось навколо.
Більш за все на світі любив дід сонце. Він прожив під сонцем коло ста літ, ніколи не ховаючись у холодок. Так під сонцем на погребні, коло яблуні, він і помер, коли прийшов його час.

Дід любив кашляти. Кашляв він часом так довго й гучно, що скільки ми не старалися, ніхто не міг його як слід передражнити. Його кашель чув увесь куток. Старі люди по дідовому кашлю вгадували навіть погоду.
"""

import re
text = re.sub(r'[.,"\'-?:!;]', '', text)
text = text.split()
text = [x for x in text if len(x)>=3]
print("Кількість слів у тексті:", len(text))

q = set(text)
w = list(q)
print("Кількість слів, що зустрічаються у тексті один раз або більше (враховуючи регістр):", len(w))

for i in range(len(text)):
    text[i] = text[i].lower()
    i = i + 1

text_uniq = []
for i in text:
    if i not in text_uniq:
        text_uniq.append(i)
print("Кількість слів, що зустрічаються у тексті один раз або більше:", len(text_uniq))

dict1 = {}
for i in text_uniq:
    dict1[i] = text.count(i)

uniq = 0
for i in dict1:
    if dict1[i] == 1:
        uniq = uniq + 1

print("Кількість унікальних слів:", uniq)

pop = []
for i in sorted(dict1, key = dict1.get, reverse = True):
    pop.append(i)

print("ТОП-3 слів, що найчастіше зустрічаються:", pop[0:3])
# Out:
# Кількість слів у тексті: 537
# Кількість слів, що зустрічаються у тексті один раз або більше (враховуючи регістр): 434
# Кількість слів, що зустрічаються у тексті один раз або більше: 414
# Кількість унікальних слів: 355
# ТОП-3 слів, що найчастіше зустрічаються: ['дід', 'він', 'коли']

# %%
import numpy
import math
#6
import random
list_with_random_numbers = [random.randint(0,100) for i in range(1000)]
print("Максимальне число:", max(list_with_random_numbers))
print("Мінімальне число:", min(list_with_random_numbers))

mean = sum(list_with_random_numbers)/len(list_with_random_numbers)
print("Середнє значення послідовності:", mean)

list_with_random_numbers.sort()
median = list_with_random_numbers[len(list_with_random_numbers)//2]
print("Медіана послідовності:", median)

list_with_random_numbers_uniq = []
for i in list_with_random_numbers:
    if i not in list_with_random_numbers_uniq:
        list_with_random_numbers_uniq.append(i)

for i in range(len(list_with_random_numbers_uniq)):
    print("Цифра:", list_with_random_numbers_uniq[i], ", кількість входжень:", list_with_random_numbers.count(i))
    i = i + 1

e = 0
for i in range(len(list_with_random_numbers_uniq)):
    e = e + (i - mean)**2*list_with_random_numbers.count(i)
    i = i + 1
std_my = round(math.sqrt(e/(len(list_with_random_numbers) - 1)), 2)

std = round(numpy.std(list_with_random_numbers, axis = 0), 2)
print("Середнє квадратичне відхилення (власні розрахунки):", std_my, ", Середнє квадратичне відхилення (за формулою):", std)
# Out:
# Максимальне число: 100
# Мінімальне число: 0
# Середнє значення послідовності: 48.206
# Медіана послідовності: 48
# Цифра: 0 , кількість входжень: 7
# Цифра: 1 , кількість входжень: 8
# Цифра: 2 , кількість входжень: 9
# Цифра: 3 , кількість входжень: 13
# Цифра: 4 , кількість входжень: 10
# Цифра: 5 , кількість входжень: 13
# Цифра: 6 , кількість входжень: 10
# Цифра: 7 , кількість входжень: 13
# Цифра: 8 , кількість входжень: 9
# Цифра: 9 , кількість входжень: 13
# Цифра: 10 , кількість входжень: 15
# Цифра: 11 , кількість входжень: 11
# Цифра: 12 , кількість входжень: 10
# Цифра: 13 , кількість входжень: 11
# Цифра: 14 , кількість входжень: 7
# Цифра: 15 , кількість входжень: 13
# Цифра: 16 , кількість входжень: 11
# Цифра: 17 , кількість входжень: 8
# Цифра: 18 , кількість входжень: 11
# Цифра: 19 , кількість входжень: 11
# Цифра: 20 , кількість входжень: 13
# Цифра: 21 , кількість входжень: 12
# Цифра: 22 , кількість входжень: 7
# Цифра: 23 , кількість входжень: 12
# Цифра: 24 , кількість входжень: 11
# Цифра: 25 , кількість входжень: 9
# Цифра: 26 , кількість входжень: 15
# Цифра: 27 , кількість входжень: 14
# Цифра: 28 , кількість входжень: 8
# Цифра: 29 , кількість входжень: 8
# Цифра: 30 , кількість входжень: 9
# Цифра: 31 , кількість входжень: 8
# Цифра: 32 , кількість входжень: 14
# Цифра: 33 , кількість входжень: 12
# Цифра: 34 , кількість входжень: 5
# Цифра: 35 , кількість входжень: 12
# Цифра: 36 , кількість входжень: 5
# Цифра: 37 , кількість входжень: 9
# Цифра: 38 , кількість входжень: 14
# Цифра: 39 , кількість входжень: 13
# Цифра: 40 , кількість входжень: 10
# Цифра: 41 , кількість входжень: 10
# Цифра: 42 , кількість входжень: 4
# Цифра: 43 , кількість входжень: 8
# Цифра: 44 , кількість входжень: 12
# Цифра: 45 , кількість входжень: 11
# Цифра: 46 , кількість входжень: 9
# Цифра: 47 , кількість входжень: 11
# Цифра: 48 , кількість входжень: 12
# Цифра: 49 , кількість входжень: 12
# Цифра: 50 , кількість входжень: 14
# Цифра: 51 , кількість входжень: 10
# Цифра: 52 , кількість входжень: 11
# Цифра: 53 , кількість входжень: 12
# Цифра: 54 , кількість входжень: 6
# Цифра: 55 , кількість входжень: 10
# Цифра: 56 , кількість входжень: 12
# Цифра: 57 , кількість входжень: 13
# Цифра: 58 , кількість входжень: 7
# Цифра: 59 , кількість входжень: 13
# Цифра: 60 , кількість входжень: 6
# Цифра: 61 , кількість входжень: 9
# Цифра: 62 , кількість входжень: 11
# Цифра: 63 , кількість входжень: 8
# Цифра: 64 , кількість входжень: 16
# Цифра: 65 , кількість входжень: 10
# Цифра: 66 , кількість входжень: 9
# Цифра: 67 , кількість входжень: 4
# Цифра: 68 , кількість входжень: 8
# Цифра: 69 , кількість входжень: 13
# Цифра: 70 , кількість входжень: 6
# Цифра: 71 , кількість входжень: 8
# Цифра: 72 , кількість входжень: 5
# Цифра: 73 , кількість входжень: 6
# Цифра: 74 , кількість входжень: 8
# Цифра: 75 , кількість входжень: 12
# Цифра: 76 , кількість входжень: 12
# Цифра: 77 , кількість входжень: 10
# Цифра: 78 , кількість входжень: 10
# Цифра: 79 , кількість входжень: 6
# Цифра: 80 , кількість входжень: 12
# Цифра: 81 , кількість входжень: 12
# Цифра: 82 , кількість входжень: 14
# Цифра: 83 , кількість входжень: 8
# Цифра: 84 , кількість входжень: 7
# Цифра: 85 , кількість входжень: 6
# Цифра: 86 , кількість входжень: 3
# Цифра: 87 , кількість входжень: 10
# Цифра: 88 , кількість входжень: 11
# Цифра: 89 , кількість входжень: 9
# Цифра: 90 , кількість входжень: 4
# Цифра: 91 , кількість входжень: 10
# Цифра: 92 , кількість входжень: 8
# Цифра: 93 , кількість входжень: 6
# Цифра: 94 , кількість входжень: 9
# Цифра: 95 , кількість входжень: 11
# Цифра: 96 , кількість входжень: 10
# Цифра: 97 , кількість входжень: 11
# Цифра: 98 , кількість входжень: 13
# Цифра: 99 , кількість входжень: 8
# Цифра: 100 , кількість входжень: 11
# Середнє квадратичне відхилення (власні розрахунки): 29.08 , Середнє квадратичне відхилення (за формулою): 29.06
